# %% [markdown]
# Make Your Own Neural Network, Part 2

# %%
import numpy
import matplotlib.pyplot as plt
import scipy.special
# %matplotlib inline

# %%
class neuralNetwork:
    
    #Initialize the network
    def __init__(self, inputnodes, hiddennodes, outputnodes, learningrate):
        #Architecture
        self.inodes = inputnodes
        self.hnodes = hiddennodes
        self.onodes = outputnodes
        
        #Learning rate
        self.lr = learningrate
        
        #Weights
        self.wih = numpy.random.normal(0.0, pow(self.hnodes, -0.5), (self.hnodes, self.inodes))
        self.who = numpy.random.normal(0.0, pow(self.onodes, -0.5), (self.onodes, self.hnodes))
        
        #Activation Function
        self.activation_function = lambda x: scipy.special.expit(x)

    #Train the network
    def train(self, inputs_list, targets_list):
        #Inputs and Targets => 2D Arrays (column vectors)
        inputs = numpy.array(inputs_list, ndmin=2).T
        targets = numpy.array(targets_list, ndmin=2).T
        
        #Hidden Layer Evaluation
        hidden_inputs = numpy.dot(self.wih, inputs)
        hidden_outputs = self.activation_function(hidden_inputs)
        
        #Output Layer Evaluation
        final_inputs = numpy.dot(self.who, hidden_outputs)
        final_outputs = self.activation_function(final_inputs)
        
        #Calculate errors
        output_errors = targets - final_outputs
        hidden_errors = numpy.dot(self.who.T, output_errors)
        
        #Adjust hidden-output weights
        self.who += self.lr * numpy.dot((output_errors * final_outputs * (1.0 - final_outputs)),
                                     numpy.transpose(hidden_outputs))
        
        #Adjust input-hidden weights
        self.wih += self.lr * numpy.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)),
                                       numpy.transpose(inputs))
    
    #Query the network
    def query(self, inputs_list):
        #Inputs => 2D Array (column vector)
        inputs = numpy.array(inputs_list, ndmin=2).T
        
        #Hidden Layer Evaluation
        hidden_inputs = numpy.dot(self.wih, inputs)
        hidden_outputs = self.activation_function(hidden_inputs)
        
        #Output Layer Evaluation
        final_inputs = numpy.dot(self.who, hidden_outputs)
        final_outputs = self.activation_function(final_inputs)
        
        return final_outputs

# %%
#Set up NN architecture and object

input_nodes = 3
hidden_nodes = 3
output_nodes = 3

learning_rate = 0.3

n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

# %%
n.query([1.0, 0.5, -1.5])
# Out:
# array([[ 0.43440135],
#        [ 0.2638138 ],
#        [ 0.51322088]])

# %%
#Open data
data_file = open("mnist_dataset/mnist_train_100.csv", 'r')
data_list = data_file.readlines()
data_file.close()

#Print first data point
all_values = data_list[0].split(',')
image_array=numpy.asfarray(all_values[1:]).reshape((28,28))
plt.imshow(image_array,cmap='Greys',interpolation='None')

# %%
all_values = data_list[1].split(',')
image_array = numpy.asfarray(all_values[1:]).reshape((28,28))
plt.imshow(image_array,cmap='Greys', interpolation='None')

# %%
#Rescale inputs to range 0.01 - 0.99
scaled_input = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
print(scaled_input)
# Out:
# [ 0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
#   0.01        0.01        0.01        0.01        0.01        0.01        0.01
# ...

# %%
#Set number of output nodes
onodes = 10
targets = numpy.zeros(onodes) + 0.01
targets[int(all_values[0])] = 0.99

# %%
print(targets)
# Out:
# [ 0.99  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01]

# %%
#Train neural network with 100 preprocessed data examples

#Setup NN architecture
input_nodes = 784
hidden_nodes = 100
output_nodes = 10

learning_rate = 0.3

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train_100.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

#Traing record by record
for record in training_data_list:
    #Split record by commas
    all_values = record.split(',')
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    #Create target output values
    targets = numpy.zeros(output_nodes) + 0.01
    #0th value of record (i.e. all_values[0]) is label
    targets[int(all_values[0])] = 0.99
    n.train(inputs, targets)
    pass

# %%
#Test neural network on one example

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test_10.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

# %%
#Get first test record
all_values = test_data_list[0].split(',')
print(all_values[0])
# Out:
# 7

# %%
image_array = numpy.asfarray(all_values[1:]).reshape((28,28))
plt.imshow(image_array, cmap='Greys', interpolation='None')

# %%
n.query((numpy.asfarray(all_values[1:]) / 255.0 + 0.99) + 0.01)
# Out:
# array([[ 0.22387522],
#        [ 0.00650818],
#        [ 0.01818811],
#        [ 0.03106938],
#        [ 0.11182448],
#        [ 0.0092027 ],
#        [ 0.00398475],
#        [ 0.18577924],
#        [ 0.01613022],
#        [ 0.00193674]])

# %%
#Begin actual testing
scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
# Out:
# 7 correct label
# 7 network's answer
# 2 correct label
# 0 network's answer
# 1 correct label
# 1 network's answer
# 0 correct label
# 0 network's answer
# 4 correct label
# 4 network's answer
# 1 correct label
# 1 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 3 network's answer
# 5 correct label
# 4 network's answer
# 9 correct label
# 7 network's answer

# %%
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.6

# %%
#Train neural network with 60,000 preprocessed data examples

#Setup NN architecture
input_nodes = 784
hidden_nodes = 100
output_nodes = 10

learning_rate = 0.3

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

#Traing record by record
for record in training_data_list:
    #Split record by commas
    all_values = record.split(',')
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    #Create target output values
    targets = numpy.zeros(output_nodes) + 0.01
    #0th value of record (i.e. all_values[0]) is label
    targets[int(all_values[0])] = 0.99
    n.train(inputs, targets)
    pass

# %%
#Test network with 10,000 examples

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# 7 correct label
# 7 network's answer
# 2 correct label
# 2 network's answer
# 1 correct label
# 1 network's answer
# 0 correct label
# 0 network's answer
# 4 correct label
# 4 network's answer
# 1 correct label
# 1 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 5 correct label
# 6 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 6 correct label
# 6 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 1 correct label
# 1 network's answer
# 5 correct label
# 5 network's answer
# 9 correct label
# 9 network's answer
# 7 correct label
# 7 network's answer
# 3 correct label
# 3 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 6 correct label
# 6 network's answer
# 6 correct label
# 6 network's answer
# 5 correct label
# 5 network's answer
# 4 correct label
# 4 network's answer
# 0 correct label
# ...

# %%
#Adjust learning rate to 0.6 to try to improve performance score
learning_rate = 0.6

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

#Traing record by record
for record in training_data_list:
    #Split record by commas
    all_values = record.split(',')
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    #Create target output values
    targets = numpy.zeros(output_nodes) + 0.01
    #0th value of record (i.e. all_values[0]) is label
    targets[int(all_values[0])] = 0.99
    n.train(inputs, targets)
    pass

# %%
#Test network with 10,000 examples with 0.6 LR

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# 7 correct label
# 7 network's answer
# 2 correct label
# 2 network's answer
# 1 correct label
# 1 network's answer
# 0 correct label
# 0 network's answer
# 4 correct label
# 4 network's answer
# 1 correct label
# 1 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 5 correct label
# 6 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 6 correct label
# 6 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 1 correct label
# 1 network's answer
# 5 correct label
# 5 network's answer
# 9 correct label
# 9 network's answer
# 7 correct label
# 7 network's answer
# 3 correct label
# 3 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 6 correct label
# 6 network's answer
# 6 correct label
# 6 network's answer
# 5 correct label
# 5 network's answer
# 4 correct label
# 9 network's answer
# 0 correct label
# ...

# %%
#Adjust learning rate to 0.1 to try to improve performance score
learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

#Traing record by record
for record in training_data_list:
    #Split record by commas
    all_values = record.split(',')
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    #Create target output values
    targets = numpy.zeros(output_nodes) + 0.01
    #0th value of record (i.e. all_values[0]) is label
    targets[int(all_values[0])] = 0.99
    n.train(inputs, targets)
    pass

# %%
#Test network with 10,000 examples with 0.1 LR

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# 7 correct label
# 7 network's answer
# 2 correct label
# 2 network's answer
# 1 correct label
# 1 network's answer
# 0 correct label
# 0 network's answer
# 4 correct label
# 4 network's answer
# 1 correct label
# 1 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 5 correct label
# 6 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 6 correct label
# 6 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 1 correct label
# 1 network's answer
# 5 correct label
# 5 network's answer
# 9 correct label
# 9 network's answer
# 7 correct label
# 7 network's answer
# 3 correct label
# 3 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 6 correct label
# 6 network's answer
# 6 correct label
# 6 network's answer
# 5 correct label
# 5 network's answer
# 4 correct label
# 4 network's answer
# 0 correct label
# ...

# %%
#Adjust learning rate to 0.2 to try to improve performance score
learning_rate = 0.2

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

#Traing record by record
for record in training_data_list:
    #Split record by commas
    all_values = record.split(',')
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    #Create target output values
    targets = numpy.zeros(output_nodes) + 0.01
    #0th value of record (i.e. all_values[0]) is label
    targets[int(all_values[0])] = 0.99
    n.train(inputs, targets)
    pass

# %%
#Test network with 10,000 examples with 0.2 LR -- BEST PERFORMANCE SCORE

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# 7 correct label
# 7 network's answer
# 2 correct label
# 2 network's answer
# 1 correct label
# 1 network's answer
# 0 correct label
# 0 network's answer
# 4 correct label
# 4 network's answer
# 1 correct label
# 1 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 5 correct label
# 6 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 6 correct label
# 6 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 1 correct label
# 1 network's answer
# 5 correct label
# 5 network's answer
# 9 correct label
# 9 network's answer
# 7 correct label
# 7 network's answer
# 3 correct label
# 3 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 6 correct label
# 6 network's answer
# 6 correct label
# 6 network's answer
# 5 correct label
# 5 network's answer
# 4 correct label
# 4 network's answer
# 0 correct label
# ...

# %%
#Attempt to improve performance score by retraining twice (2 epochs)

epochs = 2

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.2 LR, and 2 epochs

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# 7 correct label
# 7 network's answer
# 2 correct label
# 2 network's answer
# 1 correct label
# 1 network's answer
# 0 correct label
# 0 network's answer
# 4 correct label
# 4 network's answer
# 1 correct label
# 1 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 5 correct label
# 9 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 6 correct label
# 6 network's answer
# 9 correct label
# 9 network's answer
# 0 correct label
# 0 network's answer
# 1 correct label
# 1 network's answer
# 5 correct label
# 5 network's answer
# 9 correct label
# 9 network's answer
# 7 correct label
# 7 network's answer
# 3 correct label
# 3 network's answer
# 4 correct label
# 4 network's answer
# 9 correct label
# 9 network's answer
# 6 correct label
# 6 network's answer
# 6 correct label
# 6 network's answer
# 5 correct label
# 5 network's answer
# 4 correct label
# 4 network's answer
# 0 correct label
# ...

# %%
#Attempt to improve performance score by retraining four times (4 epochs)

epochs = 4

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.2 LR, and 4 epochs

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.9578

# %%
#Attempt to improve performance score by retraining five times (5 epochs)

epochs = 4

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.2 LR, and 5 epochs

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.9566

# %%
#Attempt to improve performance score by retraining six times (6 epochs)

epochs = 6

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.2 LR, and 6 epochs

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.9556

# %%
#Attempt to improve performance score by retraining seven times (7 epochs)

epochs = 7

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.2 LR, and 7 epochs

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.9565

# %%
#Choosing 7 epochs as ideal, adjust LR to 0.1

learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

epochs = 7

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.1 LR, and 7 epochs

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.9676

# %%
#With a 0.1 LR, 5 epochs ends up producing best performance

learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

epochs = 5

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.1 LR, and 5 epochs

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.968

# %%
#Try adjusting network shape to improve performance score

#5 hidden nodes -- should not perform as well due to learning capacity limit
input_nodes = 784
hidden_nodes = 5
output_nodes = 10

learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

epochs = 5

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.1 LR, 5 epochs, and 5 hidden nodes

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.7619

# %%
#Try adjusting network shape to improve performance score

#10 hidden nodes -- should perform better than 5 hidden nodes, but not as well as 100 due to learning capacity limit
input_nodes = 784
hidden_nodes = 10
output_nodes = 10

learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

epochs = 5

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.1 LR, 5 epochs, and 10 hidden nodes

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.8907

# %%
#Try adjusting network shape to improve performance score

#200 hidden nodes -- should perform better than 100 hidden nodes
input_nodes = 784
hidden_nodes = 200
output_nodes = 10

learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

epochs = 5

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.1 LR, 5 epochs, and 200 hidden nodes

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.6648

# %%
#Try adjusting network shape to improve performance score

#500 hidden nodes -- should perform better than 100 hidden nodes
input_nodes = 784
hidden_nodes = 500
output_nodes = 10

learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

epochs = 5

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with 10,000 examples, 0.1 LR, 5 epochs, and 500 hidden nodes

#Load test data CSV into list
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

for record in test_data_list:
    all_values = record.split(',')
    correct_label = int(all_values[0])
    #print(correct_label, "correct label")
    
    #Scale and shift inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    outputs = n.query(inputs)
    #Index of highest value corresponds to predicted label
    label = numpy.argmax(outputs)
    #print(label, "network's answer")
    
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
#Calculate performance score
scorecard_array = numpy.asarray(scorecard)
print("performance = ", scorecard_array.sum() / scorecard_array.size)

# %% [markdown]
# Make Your Own Neural Network, Part 3

# %%
import scipy.misc as misc
import imageio
import glob
import matplotlib.pyplot

#img_array = misc.imread(img.png, flatten=True)

#img_data = 255.0 - img_array.reshape(784)
#img_data = (img_data / 255.0 * 0.99) + 0.01

# %%
#Train as normal with MNIST data set

input_nodes = 784
hidden_nodes = 200
output_nodes = 10

learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

epochs = 5

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test with user-generated images (using examples from MYON github)
our_own_dataset = []

# load the png image data as test data set
for image_file_name in glob.glob('my_own_images/2828_my_own_?.png'):
    
    # use the filename to set the correct label
    label = int(image_file_name[-5:-4])
    
    # load image data from png files into an array
    print ("loading ... ", image_file_name)
    img_array = imageio.imread(image_file_name, as_gray=True)
    
    # reshape from 28x28 to list of 784 values, invert values
    img_data  = 255.0 - img_array.reshape(784)
    
    # then scale data to range from 0.01 to 1.0
    img_data = (img_data / 255.0 * 0.99) + 0.01
    print(numpy.min(img_data))
    print(numpy.max(img_data))
    
    # append label and image data  to test data set
    record = numpy.append(label,img_data)
    our_own_dataset.append(record)
    
    pass
# Out:
# loading ...  my_own_images\2828_my_own_2.png
# 0.01
# 1.0
# loading ...  my_own_images\2828_my_own_3.png
# 0.01
# 1.0
# loading ...  my_own_images\2828_my_own_4.png
# 0.01
# 0.930118
# loading ...  my_own_images\2828_my_own_5.png
# 0.01
# 0.868
# loading ...  my_own_images\2828_my_own_6.png
# 0.01
# 1.0

# %%
# test the neural network with our own images

# test first record
item = 0

# plot image
matplotlib.pyplot.imshow(our_own_dataset[item][1:].reshape(28,28), cmap='Greys', interpolation='None')

# correct answer is first value
correct_label = our_own_dataset[item][0]
# data is remaining values
inputs = our_own_dataset[item][1:]

# query the network
outputs = n.query(inputs)
print (outputs)

# the index of the highest value corresponds to the label
label = numpy.argmax(outputs)
print("network says ", label)
# append correct or incorrect to list
if (label == correct_label):
    print ("match!")
else:
    print ("no match!")
    pass
# Out:
# [[  5.26657401e-03]
#  [  1.52019168e-02]
#  [  6.76653025e-01]
#  [  1.93511192e-01]
#  [  6.39335428e-03]
#  [  2.93947942e-02]
#  [  4.63261282e-04]
#  [  7.90476657e-02]
#  [  1.50672162e-04]
#  [  6.59835032e-03]]
# network says  2
# match!

# %%
# test the neural network with our own images

# test second record
item = 1

# plot image
matplotlib.pyplot.imshow(our_own_dataset[item][1:].reshape(28,28), cmap='Greys', interpolation='None')

# correct answer is first value
correct_label = our_own_dataset[item][0]
# data is remaining values
inputs = our_own_dataset[item][1:]

# query the network
outputs = n.query(inputs)
print (outputs)

# the index of the highest value corresponds to the label
label = numpy.argmax(outputs)
print("network says ", label)
# append correct or incorrect to list
if (label == correct_label):
    print ("match!")
else:
    print ("no match!")
    pass
# Out:
# [[  5.59961230e-03]
#  [  6.06876152e-03]
#  [  1.46952038e-03]
#  [  9.18355953e-01]
#  [  4.34351508e-04]
#  [  3.23139880e-02]
#  [  9.85325895e-04]
#  [  1.12136738e-02]
#  [  1.45515108e-04]
#  [  3.64338082e-03]]
# network says  3
# match!

# %%
# test the neural network with our own images

# test third record
item = 2

# plot image
matplotlib.pyplot.imshow(our_own_dataset[item][1:].reshape(28,28), cmap='Greys', interpolation='None')

# correct answer is first value
correct_label = our_own_dataset[item][0]
# data is remaining values
inputs = our_own_dataset[item][1:]

# query the network
outputs = n.query(inputs)
print (outputs)

# the index of the highest value corresponds to the label
label = numpy.argmax(outputs)
print("network says ", label)
# append correct or incorrect to list
if (label == correct_label):
    print ("match!")
else:
    print ("no match!")
    pass
# Out:
# [[  1.37946691e-03]
#  [  8.93472910e-04]
#  [  7.81782499e-02]
#  [  1.32581026e-03]
#  [  8.20918896e-01]
#  [  2.01759311e-02]
#  [  4.79692814e-03]
#  [  5.07645638e-02]
#  [  1.67795654e-04]
#  [  4.26792220e-03]]
# network says  4
# match!

# %%
# test the neural network with our own images

# test fourth record
item = 3

# plot image
matplotlib.pyplot.imshow(our_own_dataset[item][1:].reshape(28,28), cmap='Greys', interpolation='None')

# correct answer is first value
correct_label = our_own_dataset[item][0]
# data is remaining values
inputs = our_own_dataset[item][1:]

# query the network
outputs = n.query(inputs)
print (outputs)

# the index of the highest value corresponds to the label
label = numpy.argmax(outputs)
print("network says ", label)
# append correct or incorrect to list
if (label == correct_label):
    print ("match!")
else:
    print ("no match!")
    pass
# Out:
# [[  1.72394851e-03]
#  [  1.31202646e-03]
#  [  1.88887231e-03]
#  [  5.41670559e-02]
#  [  2.49698506e-05]
#  [  9.20982543e-01]
#  [  1.14852748e-03]
#  [  1.18689760e-02]
#  [  3.58352302e-05]
#  [  3.85539019e-03]]
# network says  5
# match!

# %%
# test the neural network with our own images

# test fifth record
item = 4

# plot image
matplotlib.pyplot.imshow(our_own_dataset[item][1:].reshape(28,28), cmap='Greys', interpolation='None')

# correct answer is first value
correct_label = our_own_dataset[item][0]
# data is remaining values
inputs = our_own_dataset[item][1:]

# query the network
outputs = n.query(inputs)
print (outputs)

# the index of the highest value corresponds to the label
label = numpy.argmax(outputs)
print("network says ", label)
# append correct or incorrect to list
if (label == correct_label):
    print ("match!")
else:
    print ("no match!")
    pass
# Out:
# [[  3.82834352e-03]
#  [  2.28904684e-02]
#  [  4.62291372e-04]
#  [  5.16524273e-03]
#  [  4.43676306e-03]
#  [  6.04151342e-02]
#  [  8.14634181e-01]
#  [  7.71686690e-02]
#  [  9.54267254e-04]
#  [  3.38376540e-03]]
# network says  6
# match!

# %%
#Backwards Query

import numpy
# scipy.special for the sigmoid function expit(), and its inverse logit()
import scipy.special
# library for plotting arrays
import matplotlib.pyplot as plt
# ensure the plots are inside this notebook, not an external window
# %matplotlib inline

# %%
class neuralNetwork:
    
    #Initialize the network
    def __init__(self, inputnodes, hiddennodes, outputnodes, learningrate):
        #Architecture
        self.inodes = inputnodes
        self.hnodes = hiddennodes
        self.onodes = outputnodes
        
        #Learning rate
        self.lr = learningrate
        
        #Weights
        self.wih = numpy.random.normal(0.0, pow(self.hnodes, -0.5), (self.hnodes, self.inodes))
        self.who = numpy.random.normal(0.0, pow(self.onodes, -0.5), (self.onodes, self.hnodes))
        
        #Activation Function
        self.activation_function = lambda x: scipy.special.expit(x)
        self.inverse_activation_function = lambda x: scipy.special.logit(x)

    #Train the network
    def train(self, inputs_list, targets_list):
        #Inputs and Targets => 2D Arrays (column vectors)
        inputs = numpy.array(inputs_list, ndmin=2).T
        targets = numpy.array(targets_list, ndmin=2).T
        
        #Hidden Layer Evaluation
        hidden_inputs = numpy.dot(self.wih, inputs)
        hidden_outputs = self.activation_function(hidden_inputs)
        
        #Output Layer Evaluation
        final_inputs = numpy.dot(self.who, hidden_outputs)
        final_outputs = self.activation_function(final_inputs)
        
        #Calculate errors
        output_errors = targets - final_outputs
        hidden_errors = numpy.dot(self.who.T, output_errors)
        
        #Adjust hidden-output weights
        self.who += self.lr * numpy.dot((output_errors * final_outputs * (1.0 - final_outputs)),
                                     numpy.transpose(hidden_outputs))
        
        #Adjust input-hidden weights
        self.wih += self.lr * numpy.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)),
                                       numpy.transpose(inputs))
    
    #Query the network
    def query(self, inputs_list):
        #Inputs => 2D Array (column vector)
        inputs = numpy.array(inputs_list, ndmin=2).T
        
        #Hidden Layer Evaluation
        hidden_inputs = numpy.dot(self.wih, inputs)
        hidden_outputs = self.activation_function(hidden_inputs)
        
        #Output Layer Evaluation
        final_inputs = numpy.dot(self.who, hidden_outputs)
        final_outputs = self.activation_function(final_inputs)
        
        return final_outputs
    
    #Backquery the neural network
    def backquery(self, targets_list):
        # transpose the targets list to a vertical array
        final_outputs = numpy.array(targets_list, ndmin=2).T
        
        # calculate the signal into the final output layer
        final_inputs = self.inverse_activation_function(final_outputs)

        # calculate the signal out of the hidden layer
        hidden_outputs = numpy.dot(self.who.T, final_inputs)
        # scale them back to 0.01 to .99
        hidden_outputs -= numpy.min(hidden_outputs)
        hidden_outputs /= numpy.max(hidden_outputs)
        hidden_outputs *= 0.98
        hidden_outputs += 0.01
        
        # calculate the signal into the hidden layer
        hidden_inputs = self.inverse_activation_function(hidden_outputs)
        
        # calculate the signal out of the input layer
        inputs = numpy.dot(self.wih.T, hidden_inputs)
        # scale them back to 0.01 to .99
        inputs -= numpy.min(inputs)
        inputs /= numpy.max(inputs)
        inputs *= 0.98
        inputs += 0.01
        
        return inputs

# %%
#Train as normal with MNIST data set

input_nodes = 784
hidden_nodes = 200
output_nodes = 10

learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

epochs = 5

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        pass
    pass

# %%
#Test the NN

#Load the mnist test data
test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

scorecard = []

#Go through all the records in the test data set
for record in test_data_list:
    all_values = record.split(',')
    #Correct answer is first value
    correct_label = int(all_values[0])
    
    #Scale and shift the inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    #Query the network
    outputs = n.query(inputs)
    #The index of the highest value corresponds to the label
    label = numpy.argmax(outputs)
    
    #Append correct or incorrect to list
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
    pass


#Calculate the performance score
scorecard_array = numpy.asarray(scorecard)
print ("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.9712

# %%
#Backquery the network with label 0

# label to test
label = 0
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99#Backquery the network with label 0

# label to test
label = 0
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.99  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01]
# [ 0.99  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01]

# %%
#Backquery the network with label 1

# label to test
label = 1
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.01  0.99  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01]

# %%
#Backquery the network with label 2

# label to test
label = 2
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.01  0.01  0.99  0.01  0.01  0.01  0.01  0.01  0.01  0.01]

# %%
#Backquery the network with label 3

# label to test
label = 3
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.01  0.01  0.01  0.99  0.01  0.01  0.01  0.01  0.01  0.01]

# %%
#Backquery the network with label 4

# label to test
label = 4
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.01  0.01  0.01  0.01  0.99  0.01  0.01  0.01  0.01  0.01]

# %%
#Backquery the network with label 5

# label to test
label = 5
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.01  0.01  0.01  0.01  0.01  0.99  0.01  0.01  0.01  0.01]

# %%
#Backquery the network with label 6

# label to test
label = 6
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.01  0.01  0.01  0.01  0.01  0.01  0.99  0.01  0.01  0.01]

# %%
#Backquery the network with label 7

# label to test
label = 7
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.99  0.01  0.01]

# %%
#Backquery the network with label 8

# label to test
label = 8
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.99  0.01]

# %%
#Backquery the network with label 9

# label to test
label = 9
# create the output signals for this label
targets = numpy.zeros(output_nodes) + 0.01
# all_values[0] is the target label for this record
targets[label] = 0.99
print(targets)

# get image data
image_data = n.backquery(targets)

# plot image data
plt.imshow(image_data.reshape(28,28), cmap='Greys', interpolation='None')
# Out:
# [ 0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.01  0.99]

# %%
#Rotate images to create new training data

import scipy.ndimage

# %%
data_file = open("mnist_dataset/mnist_train_100.csv", 'r')
data_list = data_file.readlines()
data_file.close()

# %%
#Rotate 6th image in data set
record = 6

#First need to scale pixel values
all_values = data_list[record].split(',')
scaled_input = ((numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01).reshape(28,28)

#Check that scaling worked

print(numpy.min(scaled_input))
print(numpy.max(scaled_input))
# Out:
# 0.01
# 1.0

# %%
#Plot pre-rotation image
plt.imshow(scaled_input, cmap='Greys', interpolation='None')

# %%
#Rotate img by 10 degrees counterclockwise
inputs_plus10_img = scipy.ndimage.rotate(scaled_input, 10.0, cval=0.01, order=1, reshape=False)
#Rotate img by 10 degrees clockwise
inputs_minus10_img = scipy.ndimage.rotate(scaled_input, -10.0, cval=0.01, order=1, reshape=False)

# %%
#Check that pixel values of rotated img are within 0 and 1, exclusive
print(numpy.min(inputs_plus10_img))
print(numpy.max(inputs_plus10_img))
# Out:
# 0.01
# 0.99748795356

# %%
#Plot the 10-degrees counterclockwise img
plt.imshow(inputs_plus10_img, cmap='Greys', interpolation='None')

# %%
#Plot the 10-degrees clockwise img
plt.imshow(inputs_minus10_img, cmap='Greys', interpolation='None')

# %%
#Create NN and train with original plus rotated data

input_nodes = 784
hidden_nodes = 200
output_nodes = 10

learning_rate = 0.1

#Initialize NN object
n = neuralNetwork(input_nodes, hidden_nodes, output_nodes, learning_rate)

#Load training data CSV into list
training_data_file = open("mnist_dataset/mnist_train.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

epochs = 5

for e in range(epochs):
    for record in training_data_list:
        #Split record by commas
        all_values = record.split(',')
        #Scale and shift inputs
        inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
        #Create target output values
        targets = numpy.zeros(output_nodes) + 0.01
        #0th value of record (i.e. all_values[0]) is label
        targets[int(all_values[0])] = 0.99
        #Train on original data
        n.train(inputs, targets)
        
        #Rotate image 10 degrees counterclockwise and train again
        inputs_plus10_img = scipy.ndimage.interpolation.rotate(inputs.reshape(28,28), 10, cval=0.01, order=1, reshape=False)
        n.train(inputs_plus10_img.reshape(784), targets)
        
        #Rotate image 10 degrees clockwise and train again
        inputs_minus10_img = scipy.ndimage.interpolation.rotate(inputs.reshape(28,28), 10, cval=0.01, order=1, reshape=False)
        n.train(inputs_minus10_img.reshape(784), targets)
        pass
    pass

# %%
#Test the NN

test_data_file = open("mnist_dataset/mnist_test.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

#Go through all the records in the test data set
for record in test_data_list:
    all_values = record.split(',')
    #Correct answer is first value
    correct_label = int(all_values[0])
    
    #Scale and shift the inputs
    inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    #Query the network
    outputs = n.query(inputs)
    #The index of the highest value corresponds to the label
    label = numpy.argmax(outputs)
    
    #Append correct or incorrect to list
    if (label == correct_label):
        scorecard.append(1)
    else:
        scorecard.append(0)
        pass
    
    pass

#Calculate the performance score
scorecard_array = numpy.asarray(scorecard)
print ("performance = ", scorecard_array.sum() / scorecard_array.size)
